# %%
alphabet = 'abcdefghijklmnopqrstuvwxyz'

def ceasar_decipher(sentence, offset):
  translation = ''
  for letter in sentence:
    if letter in alphabet:
      letter_index = alphabet.find(letter)
      translation += alphabet[(letter_index + offset) % 26]
    else:
      translation += letter
  return translation

def ceasar_encode(message, offset):
  translation = ''
  for letter in message:
    if letter in alphabet:
      letter_index = alphabet.find(letter)
      new_letter = alphabet[(letter_index - offset) % len(alphabet)]
      translation += new_letter
    else:
        translation += letter
  return translation

def vigenere_encode(message, keyword):
  keyword_phrase = ""
  keyword_index = 0
  decoded_message = ""
  for character in message:
    if keyword_index >= len(keyword):
      keyword_index = 0
    if character in alphabet:
      keyword_phrase += keyword[keyword_index]
      keyword_index += 1
    else:
      keyword_phrase += character
  
  for num in range(0, len(message)):
    if message[num] in alphabet:
      old_index = alphabet.find(message[num])
      offset_index = alphabet.find(keyword_phrase[num])
      new_letter= alphabet[(old_index - offset_index) % len(alphabet)]
      decoded_message += new_letter
    else:
      decoded_message += message[num]
  return decoded_message

def vigenere_cipher(message, keyword):
  keyword_phrase = ""
  keyword_index = 0
  decoded_message = ""
  for character in message:
    if keyword_index >= len(keyword):
      keyword_index = 0
    if character in alphabet:
      keyword_phrase += keyword[keyword_index]
      keyword_index += 1
    else:
      keyword_phrase += character # for spaces
  for num in range(0, len(message)):
    if message[num] in alphabet:
      old_index = alphabet.find(message[num])
      key_index = alphabet.find(keyword_phrase[num])
      decoded_text = alphabet[(old_index + key_index) % 26]
      decoded_message += decoded_text
    else:
      decoded_message += message[num]
  return decoded_message

      
print(ceasar_decipher('bqdradyuzs ygxfubxq omqemd oubtqde fa oapq kagd yqeemsqe ue qhqz yadq eqogdq!', 14))
print(ceasar_encode('performing multiple caesar ciphers to code your messages is even more secure!', 14))


print(ceasar_decipher("vhfinmxkl atox kxgwxkxw tee hy maxlx hew vbiaxkl hulhexmx. px'ee atox mh kxteer lmxi ni hnk ztfx by px ptgm mh dxxi hnk fxlltzxl ltyx.", 7))

print(vigenere_cipher('txm srom vkda gl lzlgzr qpdb? fepb ejac! ubr imn tapludwy mhfbz cza ruxzal wg zztylktoikqq!', 'friends'))

print(vigenere_encode('you were able to decode this? nice work! you are becoming quite the expert at cryptography!', 'friends'))
