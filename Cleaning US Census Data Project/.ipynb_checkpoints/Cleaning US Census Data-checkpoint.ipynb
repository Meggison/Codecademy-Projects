# %% [markdown]
# # Cleaning US Census Data

# %% [markdown]
# You just got hired as a Data Analyst at the Census Bureau, which collects census data and creates interesting visualizations and insights from it.
#
# The person who had your job before you left you all the data they had for the most recent census. It is in multiple `csv` files. They didn't use pandas, they would just look through these `csv` files manually whenever they wanted to find something. Sometimes they would copy and paste certain numbers into Excel to make charts.
#
# The thought of it makes you shiver. This is not scalable or repeatable.
#
# Your boss wants you to make some scatterplots and histograms by the end of the day. Can you get this data into `pandas` and into reasonable shape so that you can make these histograms?

# %% [markdown]
# ## Inspect the Data!

# %% [markdown]
# 1. The first visualization your boss wants you to make is a scatterplot that shows average income in a state vs proportion of women in that state.
#
#    Open some of the census `csv` files that came with the kit you downloaded. How are they named? What kind of information do they hold? Will they help us make this graph?

# %%
# The data is stored in 10 csv files, each with the same columns and number of data entries

# %% [markdown]
# 2. It will be easier to inspect this data once we have it in a DataFrame. You can't even call `.head()` on these `csv`s! How are you supposed to read them?
#
#    Using `glob`, loop through the census files available and load them into DataFrames. Then, concatenate all of those DataFrames together into one DataFrame, called something like `us_census`.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import glob

# Merges csv files into a single dataframe
files = glob.glob("states*.csv")
df_list = []
for filename in files:
    data = pd.read_csv(filename)
    df_list.append(data)
us_census = pd.concat(df_list)

# Drops unnamed column from dataframe
us_census.drop('Unnamed: 0', axis=1, inplace=True)

us_census.head()
# Out:
#             State  TotalPop Hispanic   White   Black Native  Asian Pacific  \
# 0    Rhode Island   1053661   13.36%  74.33%   5.68%  0.35%  3.25%   0.04%
# 1  South Carolina   4777576    5.06%  62.89%  28.75%  0.29%  1.25%   0.05%
# 2    South Dakota    843190    3.24%  82.50%   1.42%  9.42%  1.02%   0.04%
# 3       Tennessee   6499615    4.72%  73.49%  18.28%  0.23%  1.41%   0.04%
# 4           Texas  26538614   38.05%  44.69%  11.65%  0.26%  3.67%   0.07%
#
#         Income            GenderPop
# 0  $59,125.27       510388M_543273F
# 1  $46,296.81     2322409M_2455167F
# 2  $51,805.41       423477M_419713F
# 3  $47,328.08     3167756M_3331859F
# 4  $55,874.52   13171316M_13367298F

# %% [markdown]
# 3. Look at the `.columns` and the `.dtypes` of the `us_census` DataFrame. Are those datatypes going to hinder you as you try to make histograms?

# %%
print(us_census.columns)
print(us_census.dtypes)
# Out:
# Index(['State', 'TotalPop', 'Hispanic', 'White', 'Black', 'Native', 'Asian',
#        'Pacific', 'Income', 'GenderPop'],
#       dtype='object')
# State        object
# TotalPop      int64
# Hispanic     object
# White        object
# Black        object
# Native       object
# Asian        object
# Pacific      object
# Income       object
# GenderPop    object
# dtype: object

# %% [markdown]
# 4. Look at the `head()` of the DataFrame so that you can understand why some of these `dtypes` are objects instead of integers or floats.
#
#    Start to make a plan for how to convert these columns into the right types for manipulation.

# %%
us_census.head(15)
# Out:
#             State  TotalPop Hispanic   White   Black Native  Asian Pacific  \
# 0    Rhode Island   1053661   13.36%  74.33%   5.68%  0.35%  3.25%   0.04%
# 1  South Carolina   4777576    5.06%  62.89%  28.75%  0.29%  1.25%   0.05%
# 2    South Dakota    843190    3.24%  82.50%   1.42%  9.42%  1.02%   0.04%
# 3       Tennessee   6499615    4.72%  73.49%  18.28%  0.23%  1.41%   0.04%
# 4           Texas  26538614   38.05%  44.69%  11.65%  0.26%  3.67%   0.07%
# 5            Utah   2903379   13.47%  79.41%   1.02%  1.08%  2.20%   0.83%
# 0            Utah   2903379   13.47%  79.41%   1.02%  1.08%  2.20%   0.83%
# 1         Vermont    626604    1.61%  93.98%   0.98%  0.30%  1.24%   0.03%
# 2        Virginia   8256630    8.01%  63.27%  20.18%  0.21%  5.46%   0.06%
# 3      Washington   6985464   11.14%  72.04%   3.38%  1.41%  7.02%   0.61%
# 4   West Virginia   1851420    1.29%  92.18%   3.66%  0.15%  0.68%   0.03%
# 5       Wisconsin   5742117    6.68%  79.86%   8.20%  0.95%  2.40%   0.02%
# 0        Maryland   5930538    8.47%  52.68%  30.68%  0.20%  5.33%   0.04%
# 1   Massachusetts   6705586   11.46%  73.04%   6.83%  0.13%  5.84%   0.02%
# 2        Michigan   9900571    4.63%  72.38%  17.63%  0.48%  2.42%   0.02%
#
#         Income            GenderPop
# 0  $59,125.27       510388M_543273F
# 1  $46,296.81     2322409M_2455167F
# 2  $51,805.41       423477M_419713F
# 3  $47,328.08     3167756M_3331859F
# 4  $55,874.52   13171316M_13367298F
# 5  $63,488.92     1459229M_1444150F
# 0  $63,488.92     1459229M_1444150F
# 1  $55,602.97       308573M_318031F
# 2  $72,866.01     4060948M_4195682F
# 3  $64,493.77     3487725M_3497739F
# 4  $41,437.11       913631M_937789F
# 5  $53,898.89     2851385M_2890732F
# 0  $78,765.40            2872643M_F
# 1  $72,838.94     3249650M_3455936F
# 2  $51,201.83     4861973M_5038598F

# %% [markdown]
# ## Regex to the Rescue

# %% [markdown]
# 5. Use regex to turn the `Income` column into a format that is ready for conversion into a numerical type.

# %%
# Removes $ and , from column values 
us_census['Income'] = pd.to_numeric(us_census['Income'].replace('[\$\,]', '', regex=True))
print(us_census.dtypes)
us_census.Income
# Out:
# State         object
# TotalPop       int64
# Hispanic      object
# White         object
# Black         object
# Native        object
# Asian         object
# Pacific       object
# Income       float64
# GenderPop     object
# dtype: object
# 0    59125.27
# 1    46296.81
# 2    51805.41
# 3    47328.08
# 4    55874.52
# 5    63488.92
# 0    63488.92
# 1    55602.97
# 2    72866.01
# 3    64493.77
# 4    41437.11
# 5    53898.89
# 0    78765.40
# 1    72838.94
# 2    51201.83
# 3    62820.83
# 4    38909.92
# 5    49763.99
# 0    49763.99
# 1    47645.68
# 2    55916.47
# 3    55526.53
# 4    68728.86
# 5    76581.08
# 0    49655.25
# 1    48100.85
# 2    54271.90
# 3    56170.46
# 4    20720.54
# 5    59125.27
# 0    76581.08
# 1    47329.97
# 2    64290.75
# 3    49937.46
# 4    58188.11
# 5    49655.25
# 0    50811.08
# 1    73264.43
# 2    48017.32
# 3    59587.05
# 4    48616.23
# 5    53017.75
# 0    53017.75
# 1    53885.61
# 2    45285.80
# 3    44957.99
# 4    49181.97
# 5    78765.40
# 0    64657.80
# 1    76146.56
# 2    61827.98
# 3    75466.36
# 4    50690.19
# 5    50811.08
# 0    43296.36
# 1    70354.74
# 2    54207.82
# 3    41935.63
# 4    67264.78
# 5    64657.80
# Name: Income, dtype: float64

# %% [markdown]
# 6. Look at the `GenderPop` column. We are going to want to separate this into two columns, the `Men` column, and the `Women` column.
#
#    Split the column into those two new columns using `str.split` and separating out those results.

# %%
# splits the GenderPop column into male and female columns
gender_split = us_census['GenderPop'].str.split('_')
us_census['Men'] = gender_split.str.get(0)
us_census['Women'] = gender_split.str.get(1)

#Remove GenderPop columns
us_census.drop('GenderPop', axis=1, inplace=True)
us_census.head(15)
# Out:
#             State  TotalPop Hispanic   White   Black Native  Asian Pacific  \
# 0    Rhode Island   1053661   13.36%  74.33%   5.68%  0.35%  3.25%   0.04%
# 1  South Carolina   4777576    5.06%  62.89%  28.75%  0.29%  1.25%   0.05%
# 2    South Dakota    843190    3.24%  82.50%   1.42%  9.42%  1.02%   0.04%
# 3       Tennessee   6499615    4.72%  73.49%  18.28%  0.23%  1.41%   0.04%
# 4           Texas  26538614   38.05%  44.69%  11.65%  0.26%  3.67%   0.07%
# 5            Utah   2903379   13.47%  79.41%   1.02%  1.08%  2.20%   0.83%
# 0            Utah   2903379   13.47%  79.41%   1.02%  1.08%  2.20%   0.83%
# 1         Vermont    626604    1.61%  93.98%   0.98%  0.30%  1.24%   0.03%
# 2        Virginia   8256630    8.01%  63.27%  20.18%  0.21%  5.46%   0.06%
# 3      Washington   6985464   11.14%  72.04%   3.38%  1.41%  7.02%   0.61%
# 4   West Virginia   1851420    1.29%  92.18%   3.66%  0.15%  0.68%   0.03%
# 5       Wisconsin   5742117    6.68%  79.86%   8.20%  0.95%  2.40%   0.02%
# 0        Maryland   5930538    8.47%  52.68%  30.68%  0.20%  5.33%   0.04%
# 1   Massachusetts   6705586   11.46%  73.04%   6.83%  0.13%  5.84%   0.02%
# 2        Michigan   9900571    4.63%  72.38%  17.63%  0.48%  2.42%   0.02%
#
#      Income        Men      Women
# 0  59125.27    510388M    543273F
# 1  46296.81   2322409M   2455167F
# 2  51805.41    423477M    419713F
# 3  47328.08   3167756M   3331859F
# 4  55874.52  13171316M  13367298F
# 5  63488.92   1459229M   1444150F
# 0  63488.92   1459229M   1444150F
# 1  55602.97    308573M    318031F
# 2  72866.01   4060948M   4195682F
# 3  64493.77   3487725M   3497739F
# 4  41437.11    913631M    937789F
# 5  53898.89   2851385M   2890732F
# 0  78765.40   2872643M          F
# 1  72838.94   3249650M   3455936F
# 2  51201.83   4861973M   5038598F

# %% [markdown]
# 7. Convert both of the columns into numerical datatypes.
#
#    There is still an `M` or an `F` character in each entry! We should remove those before we convert.

# %%
# Removes M or F from Men and Women Entries
us_census['Men'] = us_census.Men.str[:-1]
us_census['Women'] = us_census.Women.str[:-1]


us_census['Men'] = pd.to_numeric(us_census['Men'])
us_census['Women'] = pd.to_numeric(us_census['Women'])
us_census.dtypes
# Out:
# State        object
# TotalPop      int64
# Hispanic     object
# White        object
# Black        object
# Native       object
# Asian        object
# Pacific      object
# Income      float64
# Men           int64
# Women       float64
# dtype: object

# %% [markdown]
# 8. Now you should have the columns you need to make the graph and make sure your boss does not slam a ruler angrily on your desk because you've wasted your whole day cleaning your data with no results to show!
#
#    Use matplotlib to make a scatterplot!
#
#    ```py
#    plt.scatter(the_women_column, the_income_column)
#    ```
#
#    Remember to call `plt.show()` to see the graph!

# %%
#Creates a figure
plt.figure()

# Plots scatter plot of Women over Income
plt.scatter(us_census['Women'], us_census['Income'])
plt.title("Scatter Plot of Income vs. Number of Women per State")
plt.xlabel("Population of Women per State")
plt.ylabel("Income (in US Dollars)")

plt.show()
plt.clf()

# %% [markdown]
# 9. You want to double check your work. You know from experience that these monstrous csv files probably have `nan` values in them! Print out your column with the number of women per state to see.
#
#    We can fill in those `nan`s by using pandas' `.fillna()` function.
#
#    You have the `TotalPop` per state, and you have the `Men` per state. As an estimate for the `nan` values in the `Women` column, you could use the `TotalPop` of that state minus the `Men` for that state.
#
#    Print out the `Women` column after filling the `nan` values to see if it worked!

# %%
print(us_census.isna().sum())
# Fill nan values in the 'Women' Column
us_census['Women'] = us_census['Women'].fillna(us_census['TotalPop'] - us_census['Men'])

print(us_census['Women'])
# Out:
# State       0
# TotalPop    0
# Hispanic    0
# White       0
# Black       0
# Native      0
# Asian       0
# Pacific     5
# Income      0
# Men         0
# Women       3
# dtype: int64
# 0      543273.0
# 1     2455167.0
# 2      419713.0
# 3     3331859.0
# 4    13367298.0
# 5     1444150.0
# 0     1444150.0
# 1      318031.0
# 2     4195682.0
# 3     3497739.0
# 4      937789.0
# 5     2890732.0
# 0     3057895.0
# 1     3455936.0
# 2     5038598.0
# 3     2727005.0
# 4     1536358.0
# 5     3081445.0
# 0     3081445.0
# 1      504536.0
# 2      939759.0
# 3     1390901.0
# 4      670717.0
# 5     4561386.0
# 0     5913084.0
# 1     1942789.0
# 2     1990780.0
# 3     6534215.0
# 4     1869213.0
# 5      543273.0
# 0     4561386.0
# 1     1051703.0
# 2    10131373.0
# 3     5049925.0
# 4      353677.0
# 5     5913084.0
# 0     5123362.0
# 1      696428.0
# 2      806083.0
# 3     6556862.0
# 4     3333382.0
# 5     1558931.0
# 0     1558931.0
# 1     1453125.0
# 2     2233145.0
# 3     2364097.0
# 4      679019.0
# 5     3057895.0
# 0     2630239.0
# 1     1841615.0
# 2      478041.0
# 3      340810.0
# 4    10045763.0
# 5     5123362.0
# 0     2489527.0
# 1      349215.0
# 2     3342840.0
# 3     1506295.0
# 4    19334329.0
# 5     2630239.0
# Name: Women, dtype: float64

# %% [markdown]
# 10. We forgot to check for duplicates! Use `.duplicated()` on your `census` DataFrame to see if we have duplicate rows in there.

# %%
us_census.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 0     True
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 0     True
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5     True
# 0     True
# 1    False
# 2    False
# 3    False
# 4    False
# 5     True
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 0     True
# 1    False
# 2    False
# 3    False
# 4    False
# 5     True
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5     True
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5     True
# dtype: bool

# %% [markdown]
# 11. Drop those duplicates using the `.drop_duplicates()` function.

# %%
us_census = us_census.drop_duplicates()

# %% [markdown]
# 12. Make the scatterplot again. Now, it should be perfect! Your job is secure, for now.

# %%
#Creates a figure
plt.figure()

# Plots updated scatter plot of Women over Income
plt.scatter(us_census['Women'], us_census['Income'])
plt.title("Scatter Plot of Income vs. Number of Women per State")
plt.xlabel("Population of Women per State")
plt.ylabel("Income (in US Dollars)")

plt.show()
plt.clf()

# %% [markdown]
# ## Histogram of Races

# %% [markdown]
# 13. Now your boss wants you to make a bunch of histograms out of the race data that you have. Look at the `.columns` again to see what the race categories are.

# %%
us_census.columns
us_census.head()
# Out:
#             State  TotalPop Hispanic   White   Black Native  Asian Pacific  \
# 0    Rhode Island   1053661   13.36%  74.33%   5.68%  0.35%  3.25%   0.04%
# 1  South Carolina   4777576    5.06%  62.89%  28.75%  0.29%  1.25%   0.05%
# 2    South Dakota    843190    3.24%  82.50%   1.42%  9.42%  1.02%   0.04%
# 3       Tennessee   6499615    4.72%  73.49%  18.28%  0.23%  1.41%   0.04%
# 4           Texas  26538614   38.05%  44.69%  11.65%  0.26%  3.67%   0.07%
#
#      Income       Men       Women
# 0  59125.27    510388    543273.0
# 1  46296.81   2322409   2455167.0
# 2  51805.41    423477    419713.0
# 3  47328.08   3167756   3331859.0
# 4  55874.52  13171316  13367298.0

# %% [markdown]
# 14. Try to make a histogram for each one!
#
#     You will have to get the columns into the numerical format, and those percentage signs will have to go.
#
#     Don't forget to fill the `nan` values with something that makes sense! You probably dropped the duplicate rows when making your last graph, but it couldn't hurt to check for duplicates again.

# %%
us_census.isna().sum()
# Out:
# State       0
# TotalPop    0
# Hispanic    0
# White       0
# Black       0
# Native      0
# Asian       0
# Pacific     4
# Income      0
# Men         0
# Women       0
# dtype: int64

# %%
races = ['Hispanic', 'White', 'Black', 'Native', 'Asian', 'Pacific']
for race in races:
    # Remove % sign from columns and change data format
    us_census[race] = pd.to_numeric(us_census[race].str[:-1])
    
# Fill nan values in Pacific Column
us_census['Pacific'] = us_census['Pacific'].fillna(100 - us_census['Hispanic'] - us_census['White'] - us_census['Black'] - us_census['Native'] - us_census['Asian'])
us_census.head(15)
# Out:
#             State  TotalPop  Hispanic  White  Black  Native  Asian  Pacific  \
# 0    Rhode Island   1053661     13.36  74.33   5.68    0.35   3.25     0.04
# 1  South Carolina   4777576      5.06  62.89  28.75    0.29   1.25     0.05
# 2    South Dakota    843190      3.24  82.50   1.42    9.42   1.02     0.04
# 3       Tennessee   6499615      4.72  73.49  18.28    0.23   1.41     0.04
# 4           Texas  26538614     38.05  44.69  11.65    0.26   3.67     0.07
# 5            Utah   2903379     13.47  79.41   1.02    1.08   2.20     0.83
# 1         Vermont    626604      1.61  93.98   0.98    0.30   1.24     0.03
# 2        Virginia   8256630      8.01  63.27  20.18    0.21   5.46     0.06
# 3      Washington   6985464     11.14  72.04   3.38    1.41   7.02     0.61
# 4   West Virginia   1851420      1.29  92.18   3.66    0.15   0.68     0.03
# 5       Wisconsin   5742117      6.68  79.86   8.20    0.95   2.40     0.02
# 0        Maryland   5930538      8.47  52.68  30.68    0.20   5.33     0.04
# 1   Massachusetts   6705586     11.46  73.04   6.83    0.13   5.84     0.02
# 2        Michigan   9900571      4.63  72.38  17.63    0.48   2.42     0.02
# 3       Minnesota   5419171      5.15  81.43   5.66    1.07   4.16     0.03
#
#      Income       Men       Women
# 0  59125.27    510388    543273.0
# 1  46296.81   2322409   2455167.0
# 2  51805.41    423477    419713.0
# 3  47328.08   3167756   3331859.0
# 4  55874.52  13171316  13367298.0
# 5  63488.92   1459229   1444150.0
# 1  55602.97    308573    318031.0
# 2  72866.01   4060948   4195682.0
# 3  64493.77   3487725   3497739.0
# 4  41437.11    913631    937789.0
# 5  53898.89   2851385   2890732.0
# 0  78765.40   2872643   3057895.0
# 1  72838.94   3249650   3455936.0
# 2  51201.83   4861973   5038598.0
# 3  62820.83   2692166   2727005.0

# %%
for race in races:
    plt.figure()
    plt.hist(us_census[race], color='lightblue')
    plt.title('Histogram of the Percentage of {} Per State'.format(race))
    plt.xlabel('Percentage')
    plt.ylabel('Frequency')
    plt.show()
    plt.clf()

# %% [markdown]
# ## Get Creative

# %% [markdown]
# 15. Phew. You've definitely impressed your boss on your first day of work.
#
#     But is there a way you really convey the power of pandas and Python over the drudgery of `csv` and Excel?
#
#     Try to make some more interesting graphs to show your boss, and the world! You may need to clean the data even more to do it, or the cleaning you have already done may give you the ease of manipulation you've been searching for.
